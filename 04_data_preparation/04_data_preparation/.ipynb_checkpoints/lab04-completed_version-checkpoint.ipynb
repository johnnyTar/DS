# %% [markdown]
# # Lab 3: Data Preparation: Data Cleaning and EDA
#
# In this lab you will be working on visualizing a dataset from the City of Berkeley containing data on calls to the Berkeley Police Department. Information about the dataset can be found [at this link](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5).
#
#
# ### Content Warning
# This lab includes an analysis of crime in Berkeley. If you feel uncomfortable with this topic, **please contact your GSI or the instructors.**

# %% [markdown]
# ---
# ## Setup
#
# In this lab, we'll perform Exploratory Data Analysis and learn some preliminary tips for working with matplotlib (a Python plotting library). Note that we configure a custom default figure size. Virtually every default aspect of matplotlib [can be customized](https://matplotlib.org/users/customizing.html).

# %%
import pandas as pd
import numpy as np
import zipfile
import matplotlib
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12, 9)

# %%
fig = plt.figure()
plt.show(fig)

# %% [markdown]
# <br/><br/>
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 1: Acquire the Data
#
# **1. Obtain data**<br/>
# To retrieve the dataset, we will use the `dsf_utils.fetch_and_cache` utility.

# %%
# just run this cell
import dsf_utils

data_dir = 'data'
data_url = 'http://www.ds100.org/sp22/resources/assets/datasets/lab03_data_sp22.zip'
file_name = 'lab03_data_sp22.zip'

dest_path = dsf_utils.fetch_and_cache(data_url=data_url, file=file_name, data_dir=data_dir)
print(f'Located at {dest_path}')
# Out:
# Using cached version that was downloaded (UTC): Fri Feb 25 12:03:43 2022
# Located at data/lab03_data_sp22.zip

# %% [markdown]
# **2. Unzip file**<br/>
# We will now directly unzip the ZIP archive and start working with the uncompressed files.

# %%
# just run this cell
my_zip = zipfile.ZipFile(dest_path, 'r')
my_zip.extractall(data_dir)

# %% [markdown]
# Note: There is no single right answer regarding whether to work with compressed files in their compressed state or to uncompress them on disk permanently. For example, if you need to work with multiple tools on the same files, or write many notebooks to analyze them—and they are not too large—it may be more convenient to uncompress them once.  But you may also have situations where you find it preferable to work with the compressed data directly.
#
# Python gives you tools for both approaches, and you should know how to perform both tasks in order to choose the one that best suits the problem at hand.

# %% [markdown]
# **3. View files**
#
# Now, we'll use the `os` package to list all files in the `data` directory. `os.walk()` recursively traverses the directory, and `os.path.join()` creates the full pathname of each file.
#
# If you're interested in learning more, check out the Python3 documentation pages for `os.walk` ([link](https://docs.python.org/3/library/os.html#os.walk)) and `os.path` ([link](https://docs.python.org/3/library/os.path.html#os.path.join)).
#
# We use Python 3 [format strings](https://docs.python.org/3/tutorial/inputoutput.html) to nicely format the printed variables `dpath` and `fpath`.

# %%
# just run this cell
import os

for root, directories, filenames in os.walk(data_dir):
    # first, print out all directories
    for directory in directories:
        dpath = os.path.join(root, directory)
        print(f"d {dpath}")
        
    # next, print out all files
    for filename in filenames:  
        fpath = os.path.join(root,filename)
        print(f"  {fpath}")
# Out:
# d data/lab03_data_sp22
# d data/secret
#   data/dummy.txt
#   data/hello_world.py
#   data/.DS_Store
#   data/lab03_data_sp22.zip
#   data/Berkeley_PD_-_Calls_for_Service.csv
#   data/ben_kurtovic.py
# d data/lab03_data_sp22/secret
#   data/lab03_data_sp22/dummy.txt
#   data/lab03_data_sp22/hello_world.py
#   data/lab03_data_sp22/Berkeley_PD_-_Calls_for_Service.csv
#   data/lab03_data_sp22/ben_kurtovic.py
#   data/lab03_data_sp22/secret/do_not_readme.md
#   data/secret/do_not_readme.md

# %% [markdown]
# In this Lab, we'll be working with the `Berkeley_PD_-_Calls_for_Service.csv` file. Feel free to check out the other files, though.

# %% [markdown]
# <br/><br/>
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 2: Clean and Explore the Data
#
# Let's now load the CSV file we have into a `pandas.DataFrame` object and start exploring the data.

# %%
# just run this cell
calls = pd.read_csv("data/Berkeley_PD_-_Calls_for_Service.csv")
calls.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1  21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2  21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3  21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4  21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
#
#              CVLEGEND  CVDOW                InDbDate  \
# 0             LARCENY      4  06/15/2021 12:00:00 AM
# 1             LARCENY      4  06/15/2021 12:00:00 AM
# 2             LARCENY      1  06/15/2021 12:00:00 AM
# 3             LARCENY      6  06/15/2021 12:00:00 AM
# 4  BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
#
#                                       Block_Location                BLKADDR  \
# 0             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 1             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 2  2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...    2100 BLOCK HASTE ST
# 3  2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...  2600 BLOCK WARRING ST
# 4  2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...   2700 BLOCK GARBER ST
#
#        City State
# 0  Berkeley    CA
# 1  Berkeley    CA
# 2  Berkeley    CA
# 3  Berkeley    CA
# 4  Berkeley    CA

# %% [markdown]
# We see that the fields include a case number, the offense type, the date and time of the offense, the "CVLEGEND" which appears to be related to the offense type, a "CVDOW" which has no apparent meaning, a date added to the database, and the location spread across four fields. We can read more about each field from the City of the Berkeley's [open dataset webpage](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5).
#
# Let's also check some basic information about this DataFrame using the `DataFrame.info` ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)) and `DataFrame.describe` methods ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)).

# %%
# df.info() displays 
# name and type of each column,
# number of non-null entries, and
# size of dataframe
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2632 entries, 0 to 2631
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CASENO          2632 non-null   int64
#  1   OFFENSE         2632 non-null   object
#  2   EVENTDT         2632 non-null   object
#  3   EVENTTM         2632 non-null   object
#  4   CVLEGEND        2632 non-null   object
#  5   CVDOW           2632 non-null   int64
#  6   InDbDate        2632 non-null   object
#  7   Block_Location  2632 non-null   object
#  8   BLKADDR         2612 non-null   object
#  9   City            2632 non-null   object
#  10  State           2632 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 226.3+ KB

# %% [markdown]
# Note that the `BLKADDR` column only has 2612 non-null entries, while the other columns all have 2632 entries. This is because the `.info()` method only counts non-null entries.

# %%
calls.describe()
# Out:
#              CASENO        CVDOW
# count  2.632000e+03  2632.000000
# mean   2.095978e+07     3.071049
# std    2.452665e+05     1.984136
# min    2.005721e+07     0.000000
# 25%    2.100568e+07     1.000000
# 50%    2.101431e+07     3.000000
# 75%    2.102256e+07     5.000000
# max    2.109066e+07     6.000000

# %% [markdown]
# Notice that the functions above reveal type information for the columns, as well as some basic statistics about the numerical columns found in the DataFrame. However, we still need more information about what each column represents. Let's explore the data further in Question 1.
#
# Before we go over the fields to see their meanings, the cell below will verify that all the events happened in Berkeley by grouping on the `City` and `State` columns. You should see that all of our data falls into one group.

# %%
calls.groupby(["City","State"]).count()
# Out:
#                 CASENO  OFFENSE  EVENTDT  EVENTTM  CVLEGEND  CVDOW  InDbDate  \
# City     State
# Berkeley CA       2632     2632     2632     2632      2632   2632      2632
#
#                 Block_Location  BLKADDR
# City     State
# Berkeley CA               2632     2612

# %% [markdown]
# When we called `head()` on the Dataframe `calls`, it seemed like `OFFENSE` and `CVLEGEND` both contained information about the type of event reported. What is the difference in meaning between the two columns? One way to probe this is to look at the `value_counts` for each Series.

# %%
calls['OFFENSE'].value_counts().head(10)
# Out:
# THEFT MISD. (UNDER $950)    559
# VEHICLE STOLEN              277
# BURGLARY AUTO               218
# THEFT FELONY (OVER $950)    215
# DISTURBANCE                 204
# BURGLARY RESIDENTIAL        178
# VANDALISM                   166
# THEFT FROM AUTO             163
# ASSAULT/BATTERY MISD.       116
# ROBBERY                      90
# Name: OFFENSE, dtype: int64

# %%
calls['CVLEGEND'].value_counts().head(10)
# Out:
# LARCENY                   782
# MOTOR VEHICLE THEFT       277
# BURGLARY - VEHICLE        218
# DISORDERLY CONDUCT        204
# BURGLARY - RESIDENTIAL    178
# VANDALISM                 166
# LARCENY - FROM VEHICLE    163
# ASSAULT                   150
# FRAUD                      93
# ROBBERY                    90
# Name: CVLEGEND, dtype: int64

# %% [markdown]
# It seems like `OFFENSE` is more specific than `CVLEGEND`, e.g. "LARCENY" vs. "THEFT FELONY (OVER $950)". If you're unfamiliar with the term, "larceny" is a legal term for theft of personal property.
#
# To get a sense of how many subcategories there are for each `OFFENSE`, we will set `calls_by_cvlegend_and_offense` equal to a multi-indexed series where the data is first indexed on the `CVLEGEND` and then on the `OFFENSE`, and the data is equal to the number of offenses in the database that match the respective `CVLEGEND` and `OFFENSE`. As you can see, `calls_by_cvlegend_and_offense["LARCENY", "THEFT FROM PERSON"]` returns 8 which means there are 8 instances of larceny with offense of type "THEFT FROM PERSON" in the database.

# %%
calls_by_cvlegend_and_offense = calls.groupby(["CVLEGEND", "OFFENSE"]).size()
calls_by_cvlegend_and_offense
# calls_by_cvlegend_and_offense["LARCENY", "THEFT FROM PERSON"]
# Out:
# CVLEGEND                OFFENSE
# ALL OTHER OFFENSES      MUNICIPAL CODE                1
# ARSON                   ARSON                        18
# ASSAULT                 ASSAULT/BATTERY FEL.         34
#                         ASSAULT/BATTERY MISD.       116
# BURGLARY - COMMERCIAL   BURGLARY COMMERCIAL          86
# BURGLARY - RESIDENTIAL  BURGLARY RESIDENTIAL        178
# BURGLARY - VEHICLE      BURGLARY AUTO               218
# DISORDERLY CONDUCT      DISTURBANCE                 204
# DRUG VIOLATION          NARCOTICS                    33
# FAMILY OFFENSE          DOMESTIC VIOLENCE            66
# FRAUD                   FRAUD/FORGERY                41
#                         IDENTITY THEFT               52
# KIDNAPPING              KIDNAPPING                    1
# LARCENY                 THEFT FELONY (OVER $950)    215
#                         THEFT FROM PERSON             8
#                         THEFT MISD. (UNDER $950)    559
# LARCENY - FROM VEHICLE  THEFT FROM AUTO             163
# LIQUOR LAW VIOLATION    ALCOHOL OFFENSE              20
# MISSING PERSON          MISSING ADULT                25
#                         MISSING JUVENILE              1
# MOTOR VEHICLE THEFT     VEHICLE STOLEN              277
# NOISE VIOLATION         2ND RESPONSE                  2
#                         DISTURBANCE - NOISE           1
# RECOVERED VEHICLE       VEHICLE RECOVERED             6
# ROBBERY                 ROBBERY                      90
# SEX CRIME               SEXUAL ASSAULT FEL.           7
#                         SEXUAL ASSAULT MISD.          7
# VANDALISM               VANDALISM                   166
# WEAPONS OFFENSE         BRANDISHING                  25
#                         GUN/WEAPON                   12
# dtype: int64

# %% [markdown]
# <br/>
#
# <hr style="border: 1px solid #fdb515;" />
#
# ## Question 1
#
# In the cell below, set `answer1` equal to a list of strings corresponding to the possible values for `OFFENSE` when `CVLEGEND` is "LARCENY". You can type the answer manually, or you can create an expression that automatically extracts the names.
#
# <!--
# BEGIN QUESTION
# name: q1
# -->

# %%
answer1 = list(calls_by_cvlegend_and_offense['LARCENY'].index)
answer1
# Out:
# ['THEFT FELONY (OVER $950)', 'THEFT FROM PERSON', 'THEFT MISD. (UNDER $950)']

# %%
assert isinstance(answer1, list)
assert all([isinstance(elt, str) for elt in answer1])
assert len(answer1) == 3
assert all([elt in calls['OFFENSE'].values for elt in answer1])
assert set([a.strip().upper() for a in answer1]) == set(['THEFT FELONY (OVER $950)', 'THEFT FROM PERSON', 'THEFT MISD. (UNDER $950)'])

# %% [markdown]
# <br/><br/>
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 3: Visualize the Data

# %% [markdown]
# ### Matplotlib demo
#
# You've seen some `matplotlib` in this class already, but now we will explain how to work with the object-oriented plotting API mentioned in this [matplotlib.pyplot tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html) useful. In matplotlib, plotting occurs on a set of Axes which are associated with a Figure. An analogy is that on a blank canvas (Figure), you choose a location to plot (`Axes`) and then fill it in (plot).
#
# There are two approaches to labeling and manipulating figure contents, which we'll discuss below. Approach 1 is closest to the plotting paradigm of MATLAB, the namesake of matplotlib; Approach 2 is also common because many matplotlib-based packages (such as Seaborn) explicitly return the current set of axes after plotting data. Both are essentially equivalent, and at the end of this class you'll be comfortable with both.
#
# **Approach 1**: matplotlib (or Seaborn) will auto-plot onto the current set of Axes or (if none exists) create a new figure/set of default axes. You can plot data using methods from `plt`, which is shorthand for the `matplotlib.pyplot` package. Then subsequent `plt` calls all edit the same set of default-created axes.
#
# **Approach 2**:
# After creating the initial plot, you can also use `plt.gca()` to explicitly get the current set of axes, and then edit those specific axes using axes methods. Note the method naming is slightly different!

# %% [markdown]
# As an example of the built-in plotting functionality of pandas, the following example uses `plot` method of the `Series` class to generate a `barh` plot type to visually display the value counts for `CVLEGEND`.
#
# There are also many other plots that we will explore throughout the lab.

# %% [markdown]
# **Side note:** Pandas also offers basic functionality for plotting. For example, the `DataFrame` and `Series` classes both have a `plot` method, which uses matplotlib under the hood. For now we'll focus on matplotlib itself so you get used to the syntax, but just know that convenient Pandas plotting methods exist for your own future data science exploration.
#
# Below, we show both approaches by generating a horizontal bar plot to visually display the value counts for `CVLEGEND`. See the `barh`[documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html?highlight=barh#matplotlib.pyplot.barh) for more details.

# %%
# DEMO CELL: assign demo to 1 or 2.
demo = 1

calls_cvlegend = calls['CVLEGEND'].value_counts()

if demo == 1:
    plt.barh(calls_cvlegend.index, calls_cvlegend) # creates figure and axes
    print(f"Demo {demo}: Using plt methods to update plot")
    plt.ylabel("Crime Category")               # uses most recently plotted axes
    plt.xlabel("Number of Calls")
    plt.title("Number of Calls by Crime Type")
elif demo == 2:
    print(f"Demo {demo}: Using axes methods to update plot")
    plt.barh(calls_cvlegend.index, calls_cvlegend) # creates figure and axes
    ax = plt.gca()
    ax.set_ylabel("Crime Category")
    ax.set_xlabel("Number of Calls")
    ax.set_title("Axes methods: Number of Calls by Crime Type")
else:
    print("Error: Please assign the demo variable to 1 or 2.")

plt.show()
# Out:
# Demo 1: Using plt methods to update plot

# %% [markdown]
# <br/>
#
# ### An Additional Note on Plotting in Jupyter Notebooks
#
# You may have noticed that many of our plotting code cells end with a semicolon `;` or `plt.show()`. The former prevents any extra output from the last line of the cell; the latter explicitly returns (and outputs) the figure. Try adding this to your own code in the following questions!

# %% [markdown]
# <br/>
# <hr style="border: 1px solid #fdb515;" />
#
# ## Question 2
#
# Now it is your turn to make a plot using `matplotlib`.  Let's start by transforming the data so that it is easier to work with.
#
# The `CVDOW` field isn't named helpfully and it is hard to see the meaning from the data alone. According to the website [linked](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5) at the top of this notebook, `CVDOW` is actually indicating the day that events happened. 0->Sunday, 1->Monday ... 6->Saturday.
#
# ## Question 2a
#
# Add a new column `Day` into the `calls` dataframe that has the string weekday (eg. 'Sunday') for the corresponding value in CVDOW. For example, if the first 3 values of `CVDOW` are `[3, 6, 0]`, then the first 3 values of the `Day` column should be `["Wednesday", "Saturday", "Sunday"]`.
#
# **Hint:** *Try using the [Series.map](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.map.html) function on `calls["CVDOW"]`.  Can you assign this to the new column `calls["Day"]`?*
#
# <!--
# BEGIN QUESTION
# name: q2a
# -->

# %%
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
day_indices = range(7)
indices_to_days_dict = dict(zip(day_indices, days)) # Should look like {0:"Sunday", 1:"Monday", ..., 6:"Saturday"}

calls['Day'] = calls['CVDOW'].map(indices_to_days_dict)
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1     21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2     21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3     21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4     21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
# ...        ...                       ...                     ...     ...
# 2627  20058742      BURGLARY RESIDENTIAL  12/21/2020 12:00:00 AM   12:45
# 2628  21008017               BRANDISHING  02/24/2021 12:00:00 AM   15:06
# 2629  21013239  THEFT FELONY (OVER $950)  03/24/2021 12:00:00 AM    0:00
# 2630  21018143  THEFT MISD. (UNDER $950)  04/24/2021 12:00:00 AM   18:35
# 2631  21090258             BURGLARY AUTO  02/26/2021 12:00:00 AM    2:00
#
#                     CVLEGEND  CVDOW                InDbDate  \
# 0                    LARCENY      4  06/15/2021 12:00:00 AM
# 1                    LARCENY      4  06/15/2021 12:00:00 AM
# 2                    LARCENY      1  06/15/2021 12:00:00 AM
# 3                    LARCENY      6  06/15/2021 12:00:00 AM
# 4         BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
# ...                      ...    ...                     ...
# 2627  BURGLARY - RESIDENTIAL      1  06/15/2021 12:00:00 AM
# 2628         WEAPONS OFFENSE      3  06/15/2021 12:00:00 AM
# 2629                 LARCENY      3  06/15/2021 12:00:00 AM
# 2630                 LARCENY      6  06/15/2021 12:00:00 AM
# 2631      BURGLARY - VEHICLE      5  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 0                Berkeley, CA\n(37.869058, -122.270455)
# 1                Berkeley, CA\n(37.869058, -122.270455)
# 2     2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...
# 3     2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...
# 4     2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...
# ...                                                 ...
# 2627  1300 BLOCK UNIVERSITY AVE\nBerkeley, CA\n(37.8...
# 2628  100 BLOCK SEAWALL DR\nBerkeley, CA\n(37.863611...
# 2629  2800 BLOCK HILLEGASS AVE\nBerkeley, CA\n(37.85...
# 2630  2500 BLOCK TELEGRAPH AVE\nBerkeley, CA\n(37.86...
# 2631             Berkeley, CA\n(37.869058, -122.270455)
#
#                         BLKADDR      City State        Day
# 0                           NaN  Berkeley    CA   Thursday
# 1                           NaN  Berkeley    CA   Thursday
# 2           2100 BLOCK HASTE ST  Berkeley    CA     Monday
# 3         2600 BLOCK WARRING ST  Berkeley    CA   Saturday
# 4          2700 BLOCK GARBER ST  Berkeley    CA     Monday
# ...                         ...       ...   ...        ...
# 2627  1300 BLOCK UNIVERSITY AVE  Berkeley    CA     Monday
# 2628       100 BLOCK SEAWALL DR  Berkeley    CA  Wednesday
# 2629   2800 BLOCK HILLEGASS AVE  Berkeley    CA  Wednesday
# 2630   2500 BLOCK TELEGRAPH AVE  Berkeley    CA   Saturday
# 2631                        NaN  Berkeley    CA     Friday
#
# [2632 rows x 12 columns]

# %%
assert set(calls["Day"]) == {'Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday'}
assert list(calls["Day"][:5]) == ['Thursday', 'Thursday', 'Monday', 'Saturday', 'Monday']

# %%
# just run this example cell
ax = calls['CVLEGEND'].value_counts().plot(kind='barh')
ax.set_ylabel("Crime Category")
ax.set_xlabel("Number of Calls")
ax.set_title("Number of Calls By Crime Type");

# %% [markdown]
# **Challenge (OPTIONAL):** You could also accomplish this part as a table left join with `pd.merge` ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html?highlight=merge#pandas.merge)), instead of using `Series.map`. You would need to merge `calls` with a new dataframe that just contains the days of the week. If you have time, try it out in the below cell!

# %%
# scratch space for optional challenge
dow_df = pd.DataFrame(days, columns=["Day"])

...

# %%
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1     21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2     21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3     21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4     21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
# ...        ...                       ...                     ...     ...
# 2627  20058742      BURGLARY RESIDENTIAL  12/21/2020 12:00:00 AM   12:45
# 2628  21008017               BRANDISHING  02/24/2021 12:00:00 AM   15:06
# 2629  21013239  THEFT FELONY (OVER $950)  03/24/2021 12:00:00 AM    0:00
# 2630  21018143  THEFT MISD. (UNDER $950)  04/24/2021 12:00:00 AM   18:35
# 2631  21090258             BURGLARY AUTO  02/26/2021 12:00:00 AM    2:00
#
#                     CVLEGEND  CVDOW                InDbDate  \
# 0                    LARCENY      4  06/15/2021 12:00:00 AM
# 1                    LARCENY      4  06/15/2021 12:00:00 AM
# 2                    LARCENY      1  06/15/2021 12:00:00 AM
# 3                    LARCENY      6  06/15/2021 12:00:00 AM
# 4         BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
# ...                      ...    ...                     ...
# 2627  BURGLARY - RESIDENTIAL      1  06/15/2021 12:00:00 AM
# 2628         WEAPONS OFFENSE      3  06/15/2021 12:00:00 AM
# 2629                 LARCENY      3  06/15/2021 12:00:00 AM
# 2630                 LARCENY      6  06/15/2021 12:00:00 AM
# 2631      BURGLARY - VEHICLE      5  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 0                Berkeley, CA\n(37.869058, -122.270455)
# 1                Berkeley, CA\n(37.869058, -122.270455)
# 2     2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...
# 3     2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...
# 4     2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...
# ...                                                 ...
# 2627  1300 BLOCK UNIVERSITY AVE\nBerkeley, CA\n(37.8...
# 2628  100 BLOCK SEAWALL DR\nBerkeley, CA\n(37.863611...
# 2629  2800 BLOCK HILLEGASS AVE\nBerkeley, CA\n(37.85...
# 2630  2500 BLOCK TELEGRAPH AVE\nBerkeley, CA\n(37.86...
# 2631             Berkeley, CA\n(37.869058, -122.270455)
#
#                         BLKADDR      City State        Day
# 0                           NaN  Berkeley    CA   Thursday
# 1                           NaN  Berkeley    CA   Thursday
# 2           2100 BLOCK HASTE ST  Berkeley    CA     Monday
# 3         2600 BLOCK WARRING ST  Berkeley    CA   Saturday
# 4          2700 BLOCK GARBER ST  Berkeley    CA     Monday
# ...                         ...       ...   ...        ...
# 2627  1300 BLOCK UNIVERSITY AVE  Berkeley    CA     Monday
# 2628       100 BLOCK SEAWALL DR  Berkeley    CA  Wednesday
# 2629   2800 BLOCK HILLEGASS AVE  Berkeley    CA  Wednesday
# 2630   2500 BLOCK TELEGRAPH AVE  Berkeley    CA   Saturday
# 2631                        NaN  Berkeley    CA     Friday
#
# [2632 rows x 12 columns]

# %% [markdown]
# ---
# ## Question 2b
#
# Now let's look at the `EVENTTM` column which indicates the time for events. Since it contains hour and minute information, let's extract the hour info and create a new column named `Hour` in the `calls` dataframe. You should save the hour as an `int`.
#
#
# **Hint:** *Your code should only require one line*.<br/>
# **Hint 2:** The vectorized `Series.str[ind]` performs integer indexing on an array entry.
#
# <!--
# BEGIN QUESTION
# name: q2b
# -->

# %%
calls["Hour"] = calls['EVENTTM'].str.split(':').str[0].astype(int)
calls["Hour"]
# Out:
# 0       10
# 1       10
# 2       12
# 3       17
# 4        6
#         ..
# 2627    12
# 2628    15
# 2629     0
# 2630    18
# 2631     2
# Name: Hour, Length: 2632, dtype: int64

# %%
assert isinstance(calls.loc[72, 'Hour'], (int, np.integer))
assert calls['Hour'][72] == 18

# %% [markdown]
# ---
# ## Question 2c
#
# Using `matplotlib`, construct a line plot with the count of the number of calls (entries in the table) for each hour of the day  **ordered by the time** (eg. `12:00 AM`, `1:00 AM`, ...). Please use the provided variable `hours` in your answer. Be sure that your axes are labeled and that your plot is titled.
#
# **Hint**: Check out the `plt.plot` method in the matplotlib [tutorial](https://matplotlib.org/stable/tutorials/introductory/pyplot.html#intro-to-pyplot), as well as our demo above.
#
# <!--
# BEGIN QUESTION
# name: q2c
#
# -->

# %%
hours = list(range(24))

number_of_calls_per_hour = calls.groupby(['Hour']).size()

plt.plot(hours, number_of_calls_per_hour)


plt.xlabel('Hour')
plt.ylabel('Number of calls')
plt.title('The number of calls per hour to the Berkeley Police Department')



# Leave this for grading purposes
ax_3d = plt.gca()

# %%
xy_data = ax_3d.lines[0].get_xydata()
expected_xy_data = np.vstack((hours, calls["Hour"].value_counts()[hours].to_numpy())).T
assert np.allclose(xy_data, expected_xy_data)

# %% [markdown]
# To better understand the time of day a report occurs we could **stratify the analysis by the day of the week.**  To do this we will use **Heat map**.
#
# For now, just know that a Heatmap shows the distribution of quantitative data (e.g., distribution of calls by hour) over a categorical variable (day of the week). More calls occur in hours corresponding to the darker part of each column.

# %%
# for now, just run this cell.
# we will learn the seaborn visualization library next week.

calls.sort_values("CVDOW").groupby(["CVDOW", 'Hour']).size()
heat_df = pd.pivot_table(calls[["Day", 'Hour']], index=['Hour'], columns=["Day"], aggfunc=np.size)
heat_df = heat_df.reindex(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'], axis=1).sort_index(ascending=False)

import seaborn as sns
ax = sns.heatmap(heat_df, annot=True, annot_kws={"size": 10} , cmap="YlGnBu")
ax.set_title("Stratified Analysis of Phone Calls by Day");

# %% [markdown]
# ---
# ## Question 2d
#
# Based on your line plot and our violin plot above, what observations can you make about the patterns of calls? Here are some dimensions to consider:
# * Are there more calls in the day or at night?
# * What are the most and least popular times?
# * Do call patterns vary by day of the week?
#
# <!--
# BEGIN QUESTION
# name: q2d
# -->

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <br/>
# <hr style="border: 1px solid #fdb515;" />
#
# ## Question 3
# In this last part of the lab, let's extract the GPS coordinates (latitude, longitude) from the `Block_Location` of each record.

# %%
# an example block location entry
calls.loc[4, 'Block_Location']
# Out:
# '2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066, -122.253407)'

# %% [markdown]
# ---
# ## Question 3a: Regular Expressions
#
#
# Use regular expressions to create a dataframe `calls_lat_lon` that has two columns titled `Lat` and `Lon`, containing the respective latitude and longitude of each record in `calls`. You should use the `Block_Location` column to extract the latitude and longitude coordinates.
#
# **Hint**: Check out the `Series.str.extract` [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.extract.html?highlight=extract#pandas.Series.str.extract).
#
#
# <!--
# BEGIN QUESTION
# name: q3a
# -->

# %%
pattern = '(\d+\.\d+), (-?\d+\.\d+)'
calls_lat_lon = calls['Block_Location'].str.extract(pattern)
calls_lat_lon.columns = ['Lat', 'Lon']


calls_lat_lon.head(10)
# Out:
#          Lat          Lon
# 0  37.869058  -122.270455
# 1  37.869058  -122.270455
# 2  37.864908  -122.267289
# 3  37.863934  -122.250262
# 4   37.86066  -122.253407
# 5  37.881957  -122.269551
# 6  37.867426  -122.269138
# 7  37.858116  -122.268002
# 8  37.868355  -122.274953
# 9  37.851491   -122.28563

# %%
assert calls_lat_lon.shape == (2632, 2)
assert set(calls_lat_lon.columns) == {"Lat", "Lon"}

# %% [markdown]
# ---
#
# ## Question 3b: Join Tables
#
# Let's include the GPS data into our `calls` data. In the below cell, use `calls_lat_lon` to add two new columns called `Lat` and `Lon` to the `calls` dataframe.
#
# **Hint**: `pd.merge` ([documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html?highlight=merge#pandas.DataFrame.merge)) could be useful here. Note that the order of records in `calls` and `calls_lat_lon` are the same.
#
# <!--
# BEGIN QUESTION
# name: q3b
# -->

# %%
calls['Lat'] = calls_lat_lon['Lat']
calls['Lon'] = calls_lat_lon['Lon']
calls.sample(5)      # random rows
# Out:
#         CASENO               OFFENSE                 EVENTDT EVENTTM  \
# 1224  21021459        VEHICLE STOLEN  05/14/2021 12:00:00 AM   13:00
# 668   21014638  ASSAULT/BATTERY FEL.  04/03/2021 12:00:00 AM    1:05
# 653   21000846             VANDALISM  12/31/2020 12:00:00 AM   17:00
# 971   21010054             NARCOTICS  03/07/2021 12:00:00 AM   17:45
# 1174  21007044           DISTURBANCE  02/18/2021 12:00:00 AM   22:00
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 1224  MOTOR VEHICLE THEFT      5  06/15/2021 12:00:00 AM
# 668               ASSAULT      6  06/15/2021 12:00:00 AM
# 653             VANDALISM      4  06/15/2021 12:00:00 AM
# 971        DRUG VIOLATION      0  06/15/2021 12:00:00 AM
# 1174   DISORDERLY CONDUCT      4  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 1224  1500 BLOCK WARD ST\nBerkeley, CA\n(37.857856, ...
# 668   2300 BLOCK PIEDMONT AVE\nBerkeley, CA\n(37.869...
# 653   1700 BLOCK MARIN AVE\nBerkeley, CA\n(37.889482...
# 971   2400 BLOCK MARTIN LUTHER KING JR WAY\nBerkeley...
# 1174  2600 BLOCK DURANT AVE\nBerkeley, CA\n(37.86816...
#
#                                    BLKADDR      City State       Day  Hour  \
# 1224                    1500 BLOCK WARD ST  Berkeley    CA    Friday    13
# 668                2300 BLOCK PIEDMONT AVE  Berkeley    CA  Saturday     1
# 653                   1700 BLOCK MARIN AVE  Berkeley    CA  Thursday    17
# 971   2400 BLOCK MARTIN LUTHER KING JR WAY  Berkeley    CA    Sunday    17
# 1174                 2600 BLOCK DURANT AVE  Berkeley    CA  Thursday    22
#
#             Lat          Lon
# 1224  37.857856  -122.279721
# 668   37.869839  -122.252365
# 653   37.889482  -122.281718
# 971   37.865059  -122.272291
# 1174  37.868164  -122.256314

# %%
assert ('Lat' in calls.columns) and ('Lon' in calls.columns)
assert str(calls.loc[1137, "Lat"]) == '37.864925'
assert str(calls.loc[689]["Lon"]) == '-122.281739'

# %% [markdown]
# ---
# ## Question 3c: Check for Missing Values
#
# It seems like every record has valid GPS coordinates:

# %%
# just run this cell
# fraction of valid lat/lon entries
(~calls[["Lat", "Lon"]].isna()).mean()
# Out:
# Lat    1.0
# Lon    1.0
# dtype: float64

# %% [markdown]
# However, a closer examination of the data reveals something else. Here's the first few records of our data again:

# %%
calls.head(5)
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1  21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2  21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3  21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4  21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
#
#              CVLEGEND  CVDOW                InDbDate  \
# 0             LARCENY      4  06/15/2021 12:00:00 AM
# 1             LARCENY      4  06/15/2021 12:00:00 AM
# 2             LARCENY      1  06/15/2021 12:00:00 AM
# 3             LARCENY      6  06/15/2021 12:00:00 AM
# 4  BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
#
#                                       Block_Location                BLKADDR  \
# 0             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 1             Berkeley, CA\n(37.869058, -122.270455)                    NaN
# 2  2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...    2100 BLOCK HASTE ST
# 3  2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...  2600 BLOCK WARRING ST
# 4  2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...   2700 BLOCK GARBER ST
#
#        City State       Day  Hour        Lat          Lon
# 0  Berkeley    CA  Thursday    10  37.869058  -122.270455
# 1  Berkeley    CA  Thursday    10  37.869058  -122.270455
# 2  Berkeley    CA    Monday    12  37.864908  -122.267289
# 3  Berkeley    CA  Saturday    17  37.863934  -122.250262
# 4  Berkeley    CA    Monday     6   37.86066  -122.253407

# %% [markdown]
# There is another field that tells us whether we have a valid `Block_Location` entry per record---i.e., with GPS coordinates (latitude, longitude) that match the listed block location. What is it?
#
# In the below cell, use the field you found to create a new dataframe, `missing_lat_lon`, that contains only the rows of `calls` that have invalid latitude and longitude data. Your new dataframe should have all the same columns of `calls`.
#
# <!--
# BEGIN QUESTION
# name: q3c
# -->

# %%
missing_lat_lon = calls[calls['BLKADDR'].isna()]
missing_lat_lon.head()
# Out:
#        CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0    21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1    21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 215  21019124      BURGLARY RESIDENTIAL  04/30/2021 12:00:00 AM   10:00
# 260  21000289            VEHICLE STOLEN  01/01/2021 12:00:00 AM   12:00
# 633  21013362             BURGLARY AUTO  03/27/2021 12:00:00 AM    4:20
#
#                    CVLEGEND  CVDOW                InDbDate  \
# 0                   LARCENY      4  06/15/2021 12:00:00 AM
# 1                   LARCENY      4  06/15/2021 12:00:00 AM
# 215  BURGLARY - RESIDENTIAL      5  06/15/2021 12:00:00 AM
# 260     MOTOR VEHICLE THEFT      5  06/15/2021 12:00:00 AM
# 633      BURGLARY - VEHICLE      6  06/15/2021 12:00:00 AM
#
#                              Block_Location BLKADDR      City State       Day  \
# 0    Berkeley, CA\n(37.869058, -122.270455)     NaN  Berkeley    CA  Thursday
# 1    Berkeley, CA\n(37.869058, -122.270455)     NaN  Berkeley    CA  Thursday
# 215  Berkeley, CA\n(37.869058, -122.270455)     NaN  Berkeley    CA    Friday
# 260  Berkeley, CA\n(37.869058, -122.270455)     NaN  Berkeley    CA    Friday
# 633  Berkeley, CA\n(37.869058, -122.270455)     NaN  Berkeley    CA  Saturday
#
#      Hour        Lat          Lon
# 0      10  37.869058  -122.270455
# 1      10  37.869058  -122.270455
# 215    10  37.869058  -122.270455
# 260    12  37.869058  -122.270455
# 633     4  37.869058  -122.270455

# %%
assert missing_lat_lon.shape == (20, 15)
assert missing_lat_lon["BLKADDR"].isna().sum() == len(missing_lat_lon)

# %% [markdown]
# ---
#
# ## Question 3d: Check Missing Values
#
# Now let us explore if there is a pattern to which types of records have missing latitude and longitude entries.
#
# We've implemented the plotting code for you below, but read through it and verify you understand what we're doing (we've thrown in a bonus `plt.subplots()` call, documentation [here](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html#stacking-subplots-in-one-direction)).

# %%
# just run this cell
missing_by_time = (pd.to_datetime(missing_lat_lon['EVENTDT'])
                   .value_counts()
                   .sort_index()
                  )
missing_by_crime = (missing_lat_lon['CVLEGEND']
                    .value_counts() 
                    / calls['CVLEGEND'].value_counts()
                   ).dropna().sort_values(ascending=False)

fig, ax = plt.subplots(2)
ax[0].bar(missing_by_time.index, missing_by_time)
ax[0].set_ylabel("Calls with Missing Data")
ax[1].barh(missing_by_crime.index, missing_by_crime)
ax[1].set_xlabel("Fraction of Missing Data per Event Type")
fig.suptitle("Characteristics of Missing Lat/Lon Data")
plt.show()

# %% [markdown]
# <!--
# BEGIN QUESTION
# name: q3d
# -->
#
# Based on the plots above, are there any patterns among entries that are missing latitude/longitude data? The dataset information [linked](https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5) at the top of this notebook may also give more context.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ## Question 3d: Explore
#
# The below cell plots a map of phonecalls by GPS coordinates (latitude, longitude); we drop missing location data.

# %%
# just run this cell
import folium
import folium.plugins

SF_COORDINATES = (37.87, -122.28)
sf_map = folium.Map(location=SF_COORDINATES, zoom_start=13)
locs = calls.drop(missing_lat_lon.index)[['Lat', 'Lon']].astype('float').values
heatmap = folium.plugins.HeatMap(locs.tolist(), radius=10)
sf_map.add_child(heatmap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53962429fbefa05bd263760cac895a47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53962429fbefa05bd263760cac895a47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53962429fbefa05bd263760cac895a47 = L.map(
#                 &quot;map_53962429fbefa05bd263760cac895a47&quot;,
#                 {
#                     center: [37.87, -122.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69f0b06ff4e3099fdc3f4c4053df0cbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_53962429fbefa05bd263760cac895a47);
#
#
#             var heat_map_d6e46d6efe820a81d456cd5b14dbe345 = L.heatLayer(
#                 [[37.864908, -122.267289], [37.863934, -122.250262], [37.86066, -122.253407], [37.881957, -122.269551], [37.867426, -122.269138], [37.858116, -122.268002], [37.868355, -122.274953], [37.851491, -122.28563], [37.882033, -122.296381], [37.868714, -122.259189], [37.868785, -122.272701], [37.871828, -122.270516], [37.855076, -122.292412], [37.880376, -122.268183], [37.856769, -122.27984], [37.887344, -122.277321], [37.851516, -122.280088], [37.876897, -122.28868], [37.8719, -122.268389], [37.852174, -122.267824], [37.878642, -122.279173], [37.876595, -122.267789], [37.850001, -122.275963], [37.857876, -122.286598], [37.858116, -122.268002], [37.862059, -122.281167], [37.868667, -122.313656], [37.868913, -122.28608], [37.87325, -122.293558], [37.885691, -122.27282], [37.88383, -122.266309], [37.879689, -122.271614], [37.858116, -122.268002], [37.875084, -122.300897], [37.858145, -122.277491], [37.868714, -122.259189], [37.864061, -122.29877], [37.856488, -122.257329], [37.856111, -122.260248], [37.870107, -122.276593], [37.892804, -122.285696], [37.850434, -122.272607], [37.848606, -122.279588], [37.867972, -122.263699], [37.871167, -122.268285], [37.870948, -122.27733], [37.859802, -122.267177], [37.870054, -122.284263], [37.887843, -122.270011], [37.865202, -122.257795], [37.881003, -122.293212], [37.847442, -122.281175], [37.852174, -122.267824], [37.862927, -122.258784], [37.871246, -122.274991], [37.871461, -122.270706], [37.869363, -122.268028], [37.868815, -122.292131], [37.864535, -122.262993], [37.876428, -122.291736], [37.857745, -122.23991], [37.858673, -122.273365], [37.881003, -122.293212], [37.877863, -122.308855], [37.857336, -122.290797], [37.891214, -122.282158], [37.870096, -122.283932], [37.870054, -122.284263], [37.872725, -122.277729], [37.858116, -122.268002], [37.880228, -122.295798], [37.861843, -122.269644], [37.866426, -122.269762], [37.871167, -122.268285], [37.867501, -122.291709], [37.88014, -122.297498], [37.878373, -122.262902], [37.876897, -122.28868], [37.858116, -122.268002], [37.886766, -122.282493], [37.88014, -122.297498], [37.847908, -122.277685], [37.871167, -122.268285], [37.871167, -122.268285], [37.852683, -122.276556], [37.85948, -122.266689], [37.882033, -122.296381], [37.88014, -122.297498], [37.88014, -122.297498], [37.860372, -122.25981], [37.863823, -122.252575], [37.868263, -122.296013], [37.86825, -122.300093], [37.871246, -122.274991], [37.891214, -122.282158], [37.865793, -122.301779], [37.861285, -122.259979], [37.871369, -122.292954], [37.853861, -122.26598], [37.870054, -122.284263], [37.878629, -122.260883], [37.851503, -122.278518], [37.871167, -122.268285], [37.85968, -122.255796], [37.852079, -122.278653], [37.873288, -122.299396], [37.885744, -122.278017], [37.857099, -122.263785], [37.865529, -122.282628], [37.865748, -122.253396], [37.862024, -122.251212], [37.863611, -122.317566], [37.871246, -122.274991], [37.887344, -122.277321], [37.857387, -122.261536], [37.862169, -122.267084], [37.866296, -122.28996], [37.88014, -122.297498], [37.853203, -122.279642], [37.849376, -122.294952], [37.865772, -122.267643], [37.88055, -122.304962], [37.855435, -122.259841], [37.87325, -122.293558], [37.858116, -122.268002], [37.870054, -122.284263], [37.904235, -122.26951], [37.865202, -122.257795], [37.858116, -122.268002], [37.856614, -122.267596], [37.852136, -122.273695], [37.855935, -122.250579], [37.868785, -122.272701], [37.862927, -122.258784], [37.875505, -122.298797], [37.865511, -122.309967], [37.868913, -122.28608], [37.871246, -122.274991], [37.866761, -122.258779], [37.88308, -122.274259], [37.881366, -122.289688], [37.868641, -122.29415], [37.867176, -122.267802], [37.860189, -122.294048], [37.868532, -122.274764], [37.875053, -122.26548], [37.860105, -122.261901], [37.864385, -122.290697], [37.862927, -122.258784], [37.881149

# %% [markdown]
# Based on the above map, what could be some **drawbacks** of using the location fields in this dataset to draw conclusions about crime in Berkeley? Here are some sub-questions to consider:
# * Is campus really the safest place to be?
# * Why are all the calls located on the street and often at intersections?
#
# <!--
# BEGIN QUESTION
# name: q3d
# -->

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ## 4 - Deduplication
# Duplicates are the data points that are syntactically different but represent the same real-world entities.

# %% [markdown]
# Let's take a look at the `duplicate()` function in DataFrame.

# %%
len(calls[calls.duplicated()])
# Out:
# 0

# %% [markdown]
# There are not a pair of rows that are identical.
#
# ### Note that in real-world scenarios the duplicates can differ from another other.
#
# It is important that the data scientist understands the domain of the data to discover the duplicate entries.
# Let's take a look at the dataset once again.

# %%
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     21014296  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1     21014391  THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2     21090494  THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3     21090204  THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4     21090179             BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
# ...        ...                       ...                     ...     ...
# 2627  20058742      BURGLARY RESIDENTIAL  12/21/2020 12:00:00 AM   12:45
# 2628  21008017               BRANDISHING  02/24/2021 12:00:00 AM   15:06
# 2629  21013239  THEFT FELONY (OVER $950)  03/24/2021 12:00:00 AM    0:00
# 2630  21018143  THEFT MISD. (UNDER $950)  04/24/2021 12:00:00 AM   18:35
# 2631  21090258             BURGLARY AUTO  02/26/2021 12:00:00 AM    2:00
#
#                     CVLEGEND  CVDOW                InDbDate  \
# 0                    LARCENY      4  06/15/2021 12:00:00 AM
# 1                    LARCENY      4  06/15/2021 12:00:00 AM
# 2                    LARCENY      1  06/15/2021 12:00:00 AM
# 3                    LARCENY      6  06/15/2021 12:00:00 AM
# 4         BURGLARY - VEHICLE      1  06/15/2021 12:00:00 AM
# ...                      ...    ...                     ...
# 2627  BURGLARY - RESIDENTIAL      1  06/15/2021 12:00:00 AM
# 2628         WEAPONS OFFENSE      3  06/15/2021 12:00:00 AM
# 2629                 LARCENY      3  06/15/2021 12:00:00 AM
# 2630                 LARCENY      6  06/15/2021 12:00:00 AM
# 2631      BURGLARY - VEHICLE      5  06/15/2021 12:00:00 AM
#
#                                          Block_Location  \
# 0                Berkeley, CA\n(37.869058, -122.270455)
# 1                Berkeley, CA\n(37.869058, -122.270455)
# 2     2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...
# 3     2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...
# 4     2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...
# ...                                                 ...
# 2627  1300 BLOCK UNIVERSITY AVE\nBerkeley, CA\n(37.8...
# 2628  100 BLOCK SEAWALL DR\nBerkeley, CA\n(37.863611...
# 2629  2800 BLOCK HILLEGASS AVE\nBerkeley, CA\n(37.85...
# 2630  2500 BLOCK TELEGRAPH AVE\nBerkeley, CA\n(37.86...
# 2631             Berkeley, CA\n(37.869058, -122.270455)
#
#                         BLKADDR      City State        Day  Hour        Lat  \
# 0                           NaN  Berkeley    CA   Thursday    10  37.869058
# 1                           NaN  Berkeley    CA   Thursday    10  37.869058
# 2           2100 BLOCK HASTE ST  Berkeley    CA     Monday    12  37.864908
# 3         2600 BLOCK WARRING ST  Berkeley    CA   Saturday    17  37.863934
# 4          2700 BLOCK GARBER ST  Berkeley    CA     Monday     6   37.86066
# ...                         ...       ...   ...        ...   ...        ...
# 2627  1300 BLOCK UNIVERSITY AVE  Berkeley    CA     Monday    12  37.869764
# 2628       100 BLOCK SEAWALL DR  Berkeley    CA  Wednesday    15  37.863611
# 2629   2800 BLOCK HILLEGASS AVE  Berkeley    CA  Wednesday     0   37.85968
# 2630   2500 BLOCK TELEGRAPH AVE  Berkeley    CA   Saturday    18  37.864827
# 2631                        NaN  Berkeley    CA     Friday     2  37.869058
#
#               Lon
# 0     -122.270455
# 1     -122.270455
# 2     -122.267289
# 3     -122.250262
# 4     -122.253407
# ...           ...
# 2627   -122.28655
# 2628  -122.317566
# 2629  -122.255796
# 2630  -122.258577
# 2631  -122.270455
#
# [2632 rows x 15 columns]

# %% [markdown]
# To discover the duplicates, we need to first drop the auto-generated identifiers.

# %%
calls_with_duplicate = calls.drop(['CASENO', 'InDbDate'], axis=1, inplace=False)

# %%
len(calls_with_duplicate[calls_with_duplicate.duplicated()])
# Out:
# 3

# %% [markdown]
# Now, we can use `drop_duplicates()` function to remove the duplicates from the dataframe.

# %%
calls_without_duplicate = calls_with_duplicate.drop_duplicates()
calls_without_duplicate
# Out:
#                        OFFENSE                 EVENTDT EVENTTM  \
# 0     THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:58
# 1     THEFT MISD. (UNDER $950)  04/01/2021 12:00:00 AM   10:38
# 2     THEFT MISD. (UNDER $950)  04/19/2021 12:00:00 AM   12:15
# 3     THEFT FELONY (OVER $950)  02/13/2021 12:00:00 AM   17:00
# 4                BURGLARY AUTO  02/08/2021 12:00:00 AM    6:20
# ...                        ...                     ...     ...
# 2627      BURGLARY RESIDENTIAL  12/21/2020 12:00:00 AM   12:45
# 2628               BRANDISHING  02/24/2021 12:00:00 AM   15:06
# 2629  THEFT FELONY (OVER $950)  03/24/2021 12:00:00 AM    0:00
# 2630  THEFT MISD. (UNDER $950)  04/24/2021 12:00:00 AM   18:35
# 2631             BURGLARY AUTO  02/26/2021 12:00:00 AM    2:00
#
#                     CVLEGEND  CVDOW  \
# 0                    LARCENY      4
# 1                    LARCENY      4
# 2                    LARCENY      1
# 3                    LARCENY      6
# 4         BURGLARY - VEHICLE      1
# ...                      ...    ...
# 2627  BURGLARY - RESIDENTIAL      1
# 2628         WEAPONS OFFENSE      3
# 2629                 LARCENY      3
# 2630                 LARCENY      6
# 2631      BURGLARY - VEHICLE      5
#
#                                          Block_Location  \
# 0                Berkeley, CA\n(37.869058, -122.270455)
# 1                Berkeley, CA\n(37.869058, -122.270455)
# 2     2100 BLOCK HASTE ST\nBerkeley, CA\n(37.864908,...
# 3     2600 BLOCK WARRING ST\nBerkeley, CA\n(37.86393...
# 4     2700 BLOCK GARBER ST\nBerkeley, CA\n(37.86066,...
# ...                                                 ...
# 2627  1300 BLOCK UNIVERSITY AVE\nBerkeley, CA\n(37.8...
# 2628  100 BLOCK SEAWALL DR\nBerkeley, CA\n(37.863611...
# 2629  2800 BLOCK HILLEGASS AVE\nBerkeley, CA\n(37.85...
# 2630  2500 BLOCK TELEGRAPH AVE\nBerkeley, CA\n(37.86...
# 2631             Berkeley, CA\n(37.869058, -122.270455)
#
#                         BLKADDR      City State        Day  Hour        Lat  \
# 0                           NaN  Berkeley    CA   Thursday    10  37.869058
# 1                           NaN  Berkeley    CA   Thursday    10  37.869058
# 2           2100 BLOCK HASTE ST  Berkeley    CA     Monday    12  37.864908
# 3         2600 BLOCK WARRING ST  Berkeley    CA   Saturday    17  37.863934
# 4          2700 BLOCK GARBER ST  Berkeley    CA     Monday     6   37.86066
# ...                         ...       ...   ...        ...   ...        ...
# 2627  1300 BLOCK UNIVERSITY AVE  Berkeley    CA     Monday    12  37.869764
# 2628       100 BLOCK SEAWALL DR  Berkeley    CA  Wednesday    15  37.863611
# 2629   2800 BLOCK HILLEGASS AVE  Berkeley    CA  Wednesday     0   37.85968
# 2630   2500 BLOCK TELEGRAPH AVE  Berkeley    CA   Saturday    18  37.864827
# 2631                        NaN  Berkeley    CA     Friday     2  37.869058
#
#               Lon
# 0     -122.270455
# 1     -122.270455
# 2     -122.267289
# 3     -122.250262
# 4     -122.253407
# ...           ...
# 2627   -122.28655
# 2628  -122.317566
# 2629  -122.255796
# 2630  -122.258577
# 2631  -122.270455
#
# [2629 rows x 13 columns]

# %%
set(calls_without_duplicate['BLKADDR'])
# Out:
# {'100 BLOCK ALVARADO RD',
#  '100 BLOCK AVENIDA DR',
#  '100 BLOCK HILL RD',
#  '100 BLOCK HILLCREST RD',
#  '100 BLOCK PANORAMIC WAY',
#  '100 BLOCK PARKSIDE DR',
#  '100 BLOCK SEAWALL DR',
#  '100 BLOCK SOUTHAMPTON AVE',
#  '100 BLOCK SPINNAKER WAY',
#  '100 BLOCK TUNNEL RD',
#  '100 BLOCK UNIVERSITY AVE',
#  '100 BLOCK VICENTE RD',
#  '1000 BLOCK ALLSTON WAY',
#  '1000 BLOCK ASHBY AVE',
#  '1000 BLOCK DELAWARE ST',
#  '1000 BLOCK DWIGHT WAY',
#  '1000 BLOCK EUCLID AVE',
#  '1000 BLOCK FOLGER AVE',
#  '1000 BLOCK GILMAN ST',
#  '1000 BLOCK GRAYSON ST',
#  '1000 BLOCK HARRISON ST',
#  '1000 BLOCK HEARST AVE',
#  '1000 BLOCK HEINZ AVE',
#  '1000 BLOCK JONES ST',
#  '1000 BLOCK MARIPOSA AVE',
#  '1000 BLOCK MERCED ST',
#  '1000 BLOCK MILLER AVE',
#  '1000 BLOCK MURRAY ST',
#  '1000 BLOCK PARDEE ST',
#  '1000 BLOCK SIERRA ST',
#  '1000 BLOCK SPRUCE ST',
#  '1000 BLOCK STERLING AVE',
#  '1000 BLOCK UNIVERSITY AVE',
#  '1000 BLOCK WOODSIDE RD',
#  '1017 ALLSTON WAY',
#  '1025 GILMAN',
#  '1050 GILMAN AVE',
#  '1050 GILMAN ST',
#  '1080 HEINZ AVE',
#  '1100 BLOCK 10TH ST',
#  '1100 BLOCK ADDISON ST',
#  '1100 BLOCK ALLSTON WAY',
#  '1100 BLOCK AMADOR AVE',
#  '1100 BLOCK DWIGHT WAY',
#  '1100 BLOCK EASTSHORE HWY',
#  '1100 BLOCK EUCLID AVE',
#  '1100 BLOCK FRANCISCO ST',
#  '1100 BLOCK FRESNO AVE',
#  '1100 BLOCK GILMAN ST',
#  '1100 BLOCK GLEN AVE',
#  '1100 BLOCK GRIZZLY PEAK BLVD',
#  '1100 BLOCK HEARST AVE',
#  '1100 BLOCK HIGH CT',
#  '1100 BLOCK HOPKINS ST',
#  '1100 BLOCK PAGE ST',
#  '1100 BLOCK PARKER ST',
#  '1100 BLOCK SAN PABLO AVE',
#  '1100 BLOCK SHATTUCK AVE',
#  '1100 BLOCK SPRUCE ST',
#  '1100 BLOCK STERLING AVE',
#  '1100 BLOCK SUTTER ST',
#  '1100 BLOCK UNIVERSITY AVE',
#  '1100 BLOCK WALNUT ST',
#  '1100 BLOCK WARD ST',
#  '1105 PARKER ST',
#  '1114 MILVIA ST',
#  '1128 FRANCISCO ST',
#  '1129 FRANCISCO ST',
#  '1164 GLEN AVE',
#  '1200 BLOCK 4TH ST',
#  '1200 BLOCK 5TH ST',
#  '1200 BLOCK ALLSTON WAY',
#  '1200 BLOCK ASHBY AVE',
#  '1200 BLOCK DERBY ST',
#  '1200 BLOCK EUCLID AVE',
#  '1200 BLOCK EVELYN AVE',
#  '1200 BLOCK FRANCISCO ST',
#  '1200 BLOCK GILMAN ST',
#  '1200 BLOCK GRIZZLY PEAK BLVD',
#  '1200 BLOCK HASKELL ST',
#  '1200 BLOCK HEARST AVE',
#  '1200 BLOCK HENRY ST',
#  '1200 BLOCK HOPKINS ST',
#  '1200 BLOCK MASONIC AVE',
#  '1200 BLOCK MILVIA ST',
#  '1200 BLOCK NEILSON ST',
#  '1200 BLOCK PARKER ST',
#  '1200 BLOCK QUEENS RD',
#  '1200 BLOCK ROSE ST',
#  '1200 BLOCK RUSSELL ST',
#  '1200 BLOCK SAN PABLO AVE',
#  '1200 BLOCK STANNAGE AVE',
#  '1200 BLOCK TALBOT AVE',
#  '1200 BLOCK UNIVERSITY AVE',
#  '1200 BLOCK WALNUT ST',
#  '1201 2ND ST',
#  '1215 4TH ST',
#  '1215 CARRISON ST',
#  '1224 TALBOT AVE',
#  '1232 DWIGHT WAY',
#  '1238 ADDISON ST',
#  '1250 UNIVERSITY AVE',
#  '1300 BLOCK 10TH ST',
#  '1300 BLOCK 4TH ST',
#  '1300 BLOCK ADDISON ST',
#  '1300 BLOCK ALBINA AVE',
#  '1300 BLOCK ALCATRAZ AVE',
#  '1300 BLOCK ASHBY AVE',
#  '1300 BLOCK DELAWARE ST',
#  '1300 BLOCK DWIGHT WAY',
#  '1300 BLOCK EASTSHORE HWY',
#  '1300 BLOCK EUCLID AVE',
#  '1300 BLOCK FRANCISCO ST',
#  '1300 BLOCK GILMAN ST',
#  '1300 BLOCK GRIZZLY PEAK BLVD',
#  '1300 BLOCK HASKELL ST',
#  '1300 BLOCK HEARST AVE',
#  '1300 BLOCK HENRY ST',
#  '1300 BLOCK HOPKINS ST',
#  '1300 BLOCK MARTIN LUTHER KING JR WAY',
#  '1300 BLOCK MILVIA ST',
#  '1300 BLOCK PARKER ST',
#  '1300 BLOCK PERALTA AVE',
#  '1300 BLOCK ROSE ST',
#  '1300 BLOCK SACRAMENTO ST',
#  '1300 BLOCK SAN PABLO AVE',
#  '1300 BLOCK SANTA FE AVE',
#  '1300 BLOCK SHATTUCK AVE',
#  '1300 BLOCK STANNAGE AVE',
#  '1300 BLOCK SUMMIT RD',
#  '1300 BLOCK TALBOT AVE',
#  '1300 BLOCK TOMLEE DR',
#  '1300 BLOCK UNIVERSITY AVE',
#  '1300 BLOCK WALNUT ST',
#  '1300 BLOCK WARD ST',
#  '1308 CARLETON ST',
#  '1311 8TH ST',
#  '1311 ACTON ST',
#  '1327 WALNUT ST',
#  '1395 ADA ST',
#  '1400 BLOCK 10TH ST',
#  '1400 BLOCK 67TH ST',
#  '1400 BLOCK 6TH ST',
#  '1400 BLOCK 8TH ST',
#  '1400 BLOCK ACROFT CT',
#  '1400 BLOCK ACTON ST',
#  '1400 BLOCK ADDISON ST',
#  '1400 BLOCK ASHBY AVE',
#  '1400 BLOCK DERBY ST',
#  '1400 BLOCK EDITH ST',
#  '1400 BLOCK GILMAN ST',
#  '1400 BLOCK GRANT ST',
#  '1400 BLOCK GRIZZLY PEAK BLVD',
#  '1400 BLOCK HARMON ST',
#  '1400 BLOCK HAWTHORNE TER',
#  '1400 BLOCK HEARST AVE',
#  '1400 BLOCK HENRY ST',
#  '1400 BLOCK HOPKINS ST',
#  '1400 BLOCK JOSEPHINE ST',
#  '1400 BLOCK MARTIN LUTHER KING JR WAY',
#  '1400 BLOCK MILVIA ST',
#  '1400 BLOCK NEILSON ST',
#  '1400 BLOCK PARKER ST',
#  '1400 BLOCK PERALTA AVE',
#  '1400 BLOCK RUSSELL ST',
#  '1400 BLOCK SACRAMENTO ST',
#  '1400 BLOCK SAN PABLO AVE',
#  '1400 BLOCK SCENIC AVE',
#  '1400 BLOCK SHATTUCK AVE',
#  '1400 BLOCK STANNAGE AVE',
#  '1400 BLOCK UNIVERSITY AVE',
#  '1400 BLOCK WALNUT ST',
#  '1410 66TH ST',
#  '1414 UNIVERSITY AVE',
#  '1425 SANTA FE AVE',
#  '1433 OXFORD ST',
#  '1444 WALNUT ST',
#  '1500 BLOCK 6TH ST',
#  '1500 BLOCK ACTON ST',
#  '1500 BLOCK ADDISON ST',
#  '1500 BLOCK ALCATRAZ AVE',
#  '1500 BLOCK ALLSTON WAY',
#  '1500 BLOCK ARCH ST',
#  '1500 BLOCK EDITH ST',
#  '1500 BLOCK FAIRVIEW ST',
#  '1500 BLOCK FRANCISCO ST',
#  '1500 BLOCK GRANT ST',
#  '1500 BLOCK GRIZZLY PEAK BLVD',
#  '1500 BLOCK HARMON ST',
#  '1500 BLOCK HEARST AVE',
#  '1500 BLOCK HENRY ST',
#  '1500 BLOCK HOLLY ST',
#  '1500 BLOCK HOPKINS ST',
#  '1500 BLOCK JUANITA WAY',
#  '1500 BLOCK JULIA ST',
#  '1500 BLOCK MARTIN LUTHER KING JR WAY',
#  '1500 BLOCK MCGEE AVE',
#  '1500 BLOCK MILVIA ST',
#  '1500 BLOCK PARKER ST',
#  '1500 BLOCK POSEN AVE',
#  '1500 BLOCK PRINCE ST',
#  '1500 BLOCK ROSE ST',
#  '1500 BLOCK RUSSELL ST',
#  '1500 BLOCK SACRAMENTO ST',
#  '1500 BLOCK SAN PABLO AVE',
#  '1500 BLOCK SCENIC AVE',
#  '1500 BLOCK SHATTUCK AVE',
#  '1500 BLOCK SOLANO AVE',
#  '1500 BLOCK SPRUCE ST',
#  '1500 BLOCK STANNAGE AVE',
#  '1500 BLOCK STUART ST',
#  '1500 BLOCK TYLER ST',
#  '1500 BLOCK UNIVERSITY AVE',
#  '1500 BLOCK VISALIA AVE',
#  '1500 BLOCK WALNUT ST',
#  '1500 BLOCK WARD ST',
#  '1500 BLOCK WOOLSEY ST',
#  '1500 STUART ST',
#  '1514 JOSEPHINE ST',
#  '1521 SHATTUCK AVE',
#  '1530 HAWTHORNE TER',
#  '1539 PARKER ST',
#  '1600 BLOCK 62ND ST',
#  '1600 BLOCK 63RD ST',
#  '1600 BLOCK ACTON ST',
#  '1600 BLOCK ADDISON ST',
#  '1600 BLOCK ALCATRAZ AVE',
#  '1600 BLOCK ARCH ST',
#  '1600 BLOCK ASHBY AVE',
#  '1600 BLOCK DERBY ST',
#  '1600 BLOCK DWIGHT WAY',
#  '1600 BLOCK EDITH ST',
#  '1600 BLOCK EUCLID AVE',
#  '1600 BLOCK FAIRVIEW ST',
#  '1600 BLOCK FRANCISCO ST',
#  '1600 BLOCK GRANT ST',
#  '1600 BLOCK HARMON ST',
#  '1600 BLOCK HOPKINS ST',
#  '1600 BLOCK JOSEPHINE ST',
#  '1600 BLOCK JULIA ST',
#  '1600 BLOCK MARTIN LUTHER KING JR WAY',
#  '1600 BLOCK MILVIA ST',
#  '1600 BLOCK PARKER ST',
#  '1600 BLOCK POSEN AVE',
#  '1600 BLOCK PRINCE ST',
#  '1600 BLOCK RUSSELL ST',
#  '1600 BLOCK SAN LORENZO AVE',
#  '1600 BLOCK SAN PABLO AVE',
#  '1600 BLOCK SHATTUCK AVE',
#  '1600 BLOCK SOLANO AVE',
#  '1600 BLOCK SPRUCE ST',
#  '1600 BLOCK STUART ST',
#  '1600 BLOCK TACOMA AVE',
#  '1600 BLOCK TYLER ST',
#  '1600 BLOCK UNIVERSITY AVE',
#  '1600 BLOCK VIRGINIA ST',
#  '1600 BLOCK WALNUT ST',
#  '1600 BLOCK WOOLSEY ST',
#  '1607 WARD ST',
#  '1611 62ND ST',
#  '1615 RUSSELL ST',
#  '1640 HOPKINS',
#  '1650 6TH ST',
#  '1669 OXFORD ST',
#  '1673 OXFORD ST',
#  '1700 BLOCK 5TH ST',
#  '1700 BLOCK 6TH ST',
#  '1700 BLOCK ALCATRAZ AVE',
#  '1700 BLOCK ALLSTON WAY',
#  '1700 BLOCK ARCH ST',
#  '1700 BLOCK DERBY ST',
#  '1700 BLOCK DWIGHT WAY',
#  '1700 BLOCK EASTSHORE HWY',
#  '1700 BLOCK EUCLID AVE',
#  '1700 BLOCK FAIRVIEW ST',
#  '1700 BLOCK FRANCISCO ST',
#  '1700 BLOCK HEARST AVE',
#  '1700 BLOCK HIGHLAND PL',
#  '1700 BLOCK MARIN AVE',
#  '1700 BLOCK MARTIN LUTHER KING JR WAY',
#  '1700 BLOCK MILVIA ST',
#  '1700 BLOCK PARKER ST',
#  '1700 BLOCK PRINCE ST',
#  '1700 BLOCK ROSE ST',
#  '1700 BLOCK RUSSELL ST',
#  '1700 BLOCK SAN PABLO AVE',
#  '1700 BLOCK SHATTUCK AVE',
#  '1700 BLOCK SOLANO AVE',
#  '1700 BLOCK SONOMA AVE',
#  '1700 BLOCK SPRUCE ST',
#  '1700 BLOCK STUART ST',
#  '1700 BLOCK UNIVERSITY AVE',
#  '1700 BLOCK VINE ST',
#  '1700 BLOCK WALNUT ST',
#  '1700 BLOCK WARD ST',
#  '1718 ADDISON ST',
#  '1723 5TH ST',
#  '1725 SHATTUCK AVE',
#  '1725 UNIVERSITY AVE',
#  '1727 WARD ST',
#  '1730 FOURTH ST ST',
#  '1730 OREGON ST',
#  '1732 6TH ST',
#  '1739 FRANCISCO ST',
#  '1785 4TH ST',
#  '1800 BLOCK 4TH ST',
#  '1800 BLOCK 5TH ST',
#  '1800 BLOCK 6TH ST',
#  '1800 BLOCK 7TH ST',
#  '1800 BLOCK ACTON ST',
#  '1800 BLOCK ADDISON ST',
#  '1800 BLOCK ALCATRAZ AVE',
#  '1800 BLOCK ALLSTON WAY',
#  '1800 BLOCK DERBY ST',
#  '1800 BLOCK EUCLID AVE',
#  '1800 BLOCK FAIRVIEW ST',
#  '1800 BLOCK GRANT ST',
#  '1800 BLOCK HARMON ST',
#  '1800 BLOCK HEARST AVE',
#  '1800 BLOCK HOPKINS ST',
#  '1800 BLOCK MARIN AVE',
#  '1800 BLOCK MILVIA ST',
#  '1800 BLOCK MONTEREY AVE',
#  '1800 BLOCK PARKER ST',
#  '1800 BLOCK ROSE ST',
#  '1800 BLOCK SAN LORENZO AVE',
#  '1800 BLOCK SAN PABLO AVE',
#  '1800 BLOCK SAN PEDRO AVE',
#  '1800 BLOCK SHATTUCK AVE',
#  '1800 BLOCK SOLANO AVE',
#  '1800 BLOCK SONOMA AVE',
#  '1800 BLOCK SPRUCE ST',
#  '1800 BLOCK STUART ST',
#  '1800 BLOCK TACOMA AVE',
#  '1800 BLOCK THOUSAND OAKS BLVD',
#  '1800 BLOCK UNIVERSITY AVE',
#  '1800 BLOCK VINE ST',
#  '1800 BLOCK VIRGINIA ST',
#  '1800 BLOCK WALNUT ST',
#  '1800 BLOCK WARD ST',
#  '1800 BLOCK YOSEMITE RD',
#  '1800 SOLANO AVE',
#  '1811 OREGON ST',
#  '1815 PRINCE ST',
#  '1818 ACTON ST',
#  '1820 HEARST AVE',
#  '1898 ALCATRAZ AVE',
#  '1900 ALCATRAZ AVE',
#  '1900 BLOCK 4TH ST',
#  '1900 BLOCK 7TH ST',
#  '1900 BLOCK 8TH ST',
#  '1900 BLOCK ADDISON ST',
#  '1900 BLOCK ALCATRAZ AVE',
#  '1900 BLOCK ALLSTON WAY',
#  '1900 BLOCK ASHBY AVE',
#  '1900 BLOCK DERBY ST',
#  '1900 BLOCK DWIGHT WAY',
#  '1900 BLOCK FAIRVIEW ST',
#  '1900 BLOCK FRANCISCO ST',
#  '1900 BLOCK GRANT ST',
#  '1900 BLOCK HARMON ST',
#  '1900 BLOCK HASTE ST',
#  '1900 BLOCK HEARST AVE',
#  '1900 BLOCK HOPKINS ST',
#  '1900 BLOCK MARTIN LUTHER KING JR WAY',
#  '1900 BLOCK MCGEE AVE',
#  '1900 BLOCK MILVIA ST',
#  '1900 BLOCK PARKER ST',
#  '1900 BLOCK ROSE ST',
#  '1900 BLOCK RUSSELL ST',
#  '1900 BLOCK SAN PABLO AVE',
#  '1900 BLOCK SHATTUCK AVE',
#  '1900 BLOCK UNIVERSITY AVE',
#  '1900 BLOCK VINE ST',
#  '1900 BLOCK WALNUT ST',
#  '1900 BLOCK WOOLSEY ST',
#  '1900 BLOCK YOLO AVE',
#  '1900 BLOCK YOSEMITE RD',
#  '1905 DELAWARE ST',
#  '1917 6TH ST',
#  '1998 SHATTUCK AVE',
#  '200 BLOCK ALVARADO RD',
#  '200 BLOCK FAIRLAWN DR',
#  '200 BLOCK FOREST LN',
#  '200 BLOCK HILLCREST RD',
#  '200 BLOCK MARINA BLVD',
#  '200 BLOCK PANORAMIC WAY',
#  '200 BLOCK UNIVERSITY AVE',
#  '2000 BLOCK 6TH ST',
#  '2000 BLOCK ACTON ST',
#  '2000 BLOCK ADDISON ST',
#  '2000 BLOCK ALLSTON WAY',
#  '2000 BLOCK DEL NORTE ST',
#  '2000 BLOCK DURANT AVE',
#  '2000 BLOCK DWIGHT WAY',
#  '2000 BLOCK EMERSON ST',
#  '2000 BLOCK ESSEX ST',
#  '2000 BLOCK EUNICE ST',
#  '2000 BLOCK FRANCISCO ST',
#  '2000 BLOCK HEARST AVE',
#  '2000 BLOCK MARTIN LUTHER KING JR WAY',
#  '2000 BLOCK MCGEE AVE',
#  '2000 BLOCK MILVIA ST',
#  '2000 BLOCK PARKER ST',
#  '2000 BLOCK PRINCE ST',
#  '2000 BLOCK SACRAMENTO ST',
#  '2000 BLOCK SAN PABLO AVE',
#  '2000 BLOCK SHATTUCK AVE',
#  '2000 BLOCK STUART ST',
#  '2000 BLOCK UNIVERSITY AVE',
#  '2000 BLOCK VINE ST',
#  '2000 BLOCK WARD ST',
#  '2000 BLOCK WOOLSEY ST',
#  '2012 SHATTUCK AVE',
#  '2017 GRANT ST',
#  '2020 4TH ST',
#  '2020 BANCROFT WAY',
#  '2020 KITTREDGE ST',
#  '2022 7TH ST',
#  '2032 WARD ST',
#  '2035 HEARST AVE',
#  '2060 4TH ST',
#  '2060 MCGEE AVE',
#  '2075 SACRAMENTO ST',
#  '2086 ALLSTON WAY',
#  '2100 BLOCK 5TH ST',
#  '2100 BLOCK 6TH ST',
#  '2100 BLOCK 8TH ST',
#  '2100 BLOCK ACTON ST',
#  '2100 BLOCK ALLSTON WAY',
#  '2100 BLOCK ASHBY AVE',
#  '2100 BLOCK DURANT AVE',
#  '2100 BLOCK DWIGHT WAY',
#  '2100 BLOCK EMERSON ST',
#  '2100 BLOCK ESSEX ST',
#  '2100 BLOCK EUNICE ST',
#  '2100 BLOCK GRANT ST',
#  '2100 BLOCK HASTE ST',
#  '2100 BLOCK MARTIN LUTHER KING JR WAY',
#  '2100 BLOCK MCGEE AVE',
#  '2100 BLOCK MCKINLEY AVE',
#  '2100 BLOCK MILVIA ST',
#  '2100 BLOCK PARKER ST',
#  '2100 BLOCK PRINCE ST',
#  '2100 BLOCK ROOSEVELT AVE',
#  '2100 BLOCK RUSSELL ST',
#  '2100 BLOCK SACRAMENTO ST',
#  '2100 BLOCK SAN PABLO AVE',
#  '2100 BLOCK SHATTUCK AVE',
#  '2100 BLOCK UNIVERSITY AVE',
#  '2100 BLOCK VINE ST',
#  '2100 BLOCK WARD ST',
#  '2104 PRINCE ST',
#  '2107 SPAULDING AVE',
#  '2115 HASTE ST',
#  '2115 SACRAMENTO',
#  '2118 CALIFORNIA ST',
#  '2140 DWIGHT WAY',
#  '2150 OXFORD ST',
#  '2200 BLOCK 5TH ST',
#  '2200 BLOCK ACTON ST',
#  '2200 BLOCK ASHBY AVE',
#  '2200 BLOCK DERBY ST',
#  '2200 BLOCK DURANT AVE',
#  '2200 BLOCK DWIGHT WAY',
#  '2200 BLOCK FULTON ST',
#  '2200 BLOCK GLEN AVE',
#  '2200 BLOCK GRANT ST',
#  '2200 BLOCK HASTE ST',
#  '2200 BLOCK HEARST AVE',
#  '2200 BLOCK JEFFERSON AVE',
#  '2200 BLOCK MARIN AVE',
#  '2200 BLOCK MCGEE AVE',
#  '2200 BLOCK MCKINLEY AVE',
#  '2200 BLOCK MILVIA ST',
#  '2200 BLOCK PARKER ST',
#  '2200 BLOCK PIEDMONT AVE',
#  '2200 BLOCK PRINCE ST',
#  '2200 BLOCK ROOSEVELT AVE',
#  '2200 BLOCK ROSE ST',
#  '2200 BLOCK SACRAMENTO ST',
#  '2200 BLOCK SAN PABLO AVE',
#  '2200 BLOCK SHATTUCK AVE',
#  '2200 BLOCK SPAULDING AVE',
#  '2200 BLOCK STUART ST',
#  '2200 BLOCK VINE ST',
#  '2200 BLOCK WARD ST',
#  '2200 WARD ST',
#  '2206 BYRON ST',
#  '2220 4TH ST',
#  '2300 BLOCK 4TH ST',
#  '2300 BLOCK 5TH ST',
#  '2300 BLOCK ACTON ST',
#  '2300 BLOCK DERBY ST',
#  '2300 BLOCK DURANT AVE',
#  '2300 BLOCK EDWARDS ST',
#  '2300 BLOCK ELLSWORTH ST',
#  '2300 BLOCK FULTON ST',
#  '2300 BLOCK GRANT ST',
#  '2300 BLOCK HASTE ST',
#  '2300 BLOCK JEFFERSON AVE',
#  '2300 BLOCK MARTIN LUTHER KING JR WAY',
#  '2300 BLOCK PARKER ST',
#  '2300 BLOCK PIEDMONT AVE',
#  '2300 BLOCK PRINCE ST',
#  '2300 BLOCK PROSPECT ST',
#  '2300 BLOCK RUSSELL ST',
#  '2300 BLOCK SACRAMENTO ST',
#  '2300 BLOCK SAN PABLO AVE',
#  '2300 BLOCK SHATTUCK AVE',
#  '2300 BLOCK SPAULDING AVE',
#  '2300 BLOCK STUART ST',
#  '2300 BLOCK TELEGRAPH AVE',
#  '2300 BLOCK WARD ST',
#  '2300 BLOCK WARRING ST',
#  '2300 BLOCK WEBSTER ST',
#  '2300 BLOCK WOOLSEY ST',
#  '2300 SHATTUCK AVE',
#  '2318 PARKER ST',
#  '2322 SHATTUCK AVE',
#  '2324 DWIGHT WAY',
#  '2338 8TH ST',
#  '2341 8TH ST',
#  '2362 BANCROFT WAY',
#  '2373 SAN PABLO AVE',
#  '2400 BLOCK 10TH ST',
#  '2400 BLOCK 4TH ST',
#  '2400 BLOCK ACTON ST',
#  '2400 BLOCK ASHBY AVE',
#  '2400 BLOCK ATHERTON ST',
#  '2400 BLOCK DANA ST',
#  '2400 BLOCK DERBY ST',
#  '2400 BLOCK DURANT AVE',
#  '2400 BLOCK DWIGHT WAY',
#  '2400 BLOCK ELLSWORTH ST',
#  '2400 BLOCK FULTON ST',
#  '2400 BLOCK HASTE ST',
#  '2400 BLOCK HILGARD AVE',
#  '2400 BLOCK HILLSIDE AVE',
#  '2400 BLOCK JEFFERSON AVE',
#  '2400 BLOCK MARTIN LUTHER KING JR WAY',
#  '2400 BLOCK MCKINLEY AVE',
#  '2400 BLOCK PARKER ST',
#  '2400 BLOCK PIEDMONT AVE',
#  '2400 BLOCK PRINCE ST',
#  '2400 BLOCK PROSPECT ST',
#  '2400 BLOCK RIDGE RD',
#  '2400 BLOCK ROOSEVELT AVE',
#  '2400 BLOCK SACRAMENTO ST',
#  '2400 BLOCK SAN PABLO AVE',
#  '2400 BLOCK SHATTUCK AVE',
#  '2400 BLOCK TELEGRAPH AVE',
#  '2400 BLOCK WARD ST',
#  '2400 BLOCK WARRING ST',
#  '2410 DANA ST',
#  '2419 SAN PABLO AVE',
#  '2421 SAN PABLO AVE',
#  '2423 BLAKE ST',
#  '2426 MCGEE AVE',
#  '2431 DURANT AVE',
#  '2450 ASHBY AVE',
#  '2450 DURANT AVE',
#  '2471 SHATTUCK',
#  '2491 ELLSWORTH ST',
#  '2500 BLOCK DANA ST',
#  '2500 BLOCK DURANT AVE',
#  '2500 BLOCK DWIGHT WAY',
#  '2500 BLOCK ELLSWORTH ST',
#  '2500 BLOCK ETNA ST',
#  '2500 BLOCK GRANT ST',
#  '2500 BLOCK HASTE ST',
#  '2500 BLOCK HILGARD AVE',
#  '2500 BLOCK HILLEGASS AVE',
#  '2500 BLOCK MABEL ST',
#  '2500 BLOCK MARTIN LUTHER KING JR WAY',
#  '2500 BLOCK PARKER ST',
#  '2500 BLOCK PIEDMONT AVE',
#  '2500 BLOCK PRINCE ST',
#  '2500 BLOCK REGENT ST',
#  '2500 BLOCK ROSE WALK',
#  '2500 BLOCK SACRAMENTO ST',
#  '2500 BLOCK SAN PABLO AVE',
#  '2500 BLOCK SHATTUCK AVE',
#  '2500 BLOCK STUART ST',
#  '2500 BLOCK TELEGRAPH AVE',
#  '2500 BLOCK VIRGINIA ST',
#  '2500 BLOCK WARRING ST',
#  '2511 PARKER ST',
#  '2512 REGENT ST',
#  '2519 DURANT AVE',
#  '2521 DURANT AVE',
#  '2521 TELEGRAPH AVE',
#  '2530 DWIGHT WAY',
#  '2530 SAN PABLO AVE',
#  '2532 DWIGHT WAY',
#  '2533 GRANT ST',
#  '2560 9TH ST',
#  '2568 VIRGINIA ST',
#  '2591 HILGARD AVE',
#  '26 DOMINGO AVE',
#  '2600 BLOCK 10TH ST',
#  '2600 BLOCK ALCATRAZ AVE',
#  '2600 BLOCK ASHBY AVE',
#  '2600 BLOCK DANA ST',
#  '2600 BLOCK DERBY ST',
#  '2600 BLOCK DURANT AVE',
#  '2600 BLOCK DWIGHT WAY',
#  '2600 BLOCK ELLSWORTH ST',
#  '2600 BLOCK ETNA ST',
#  '2600 BLOCK FULTON ST',
#  '2600 BLOCK GRANT ST',
#  '2600 BLOCK HASTE ST',
#  '2600 BLOCK HILGARD AVE',
#  '2600 BLOCK HILLEGASS AVE',
#  '2600 BLOCK MABEL ST',
#  '2600 BLOCK MILVIA ST',
#  '2600 BLOCK PARKER ST',
#  '2600 BLOCK PIEDMONT AVE',
#  '2600 BLOCK REGENT ST',
#  '2600 BLOCK SACRAMENTO ST',
#  '2600 BLOCK SAN PABLO AVE',
#  '2600 BLOCK SHATTUCK AVE',
#  '2600 BLOCK TELEGRAPH AVE',
#  '2600 BLOCK VIRGINIA ST',
#  '2600 BLOCK WARRING ST',
#  '2600 BLOCK WEBSTER ST',
#  '2601 WARRING ST',
#  '2651 BANCROFT WAY',
#  '2700 BLOCK 7TH ST',
#  '2700 BLOCK 9TH ST',
#  '2700 BLOCK ACTON ST',
#  '2700 BLOCK ALCATRAZ AVE',
#  '2700 BLOCK ASHBY PL',
#  '2700 BLOCK DANA ST',
#  '2700 BLOCK DERBY ST',
#  '2700 BLOCK DOHR ST',
#  '2700 BLOCK DURANT AVE',
#  '2700 BLOCK DWIGHT WAY',
#  '2700 BLOCK ELLSWORTH ST',
#  '2700 BLOCK ELMWOOD AVE',
#  '2700 BLOCK FOREST AVE',
#  '2700 BLOCK GARBER ST',
#  '2700 BLOCK GRANT ST',
#  '2700 BLOCK HASTE ST',
#  '2700 BLOCK HILLEGASS AVE',
#  '2700 BLOCK MABEL ST',
#  '2700 BLOCK MARTIN LUTHER KING JR WAY',
#  '2700 BLOCK MATHEWS ST',
#  '2700 BLOCK MILVIA ST',
#  '2700 BLOCK PARKER ST',
#  '2700 BLOCK PIEDMONT AVE',
#  '2700 BLOCK PRINCE ST',
#  '2700 BLOCK REGENT ST',
#  '2700 BLOCK RUSSELL ST',
#  '2700 BLOCK SACRAMENTO ST',
#  '2700 BLOCK SAN PABLO AVE',
#  '2700 BLOCK SHASTA RD',
#  '2700 BLOCK SHATTUCK AVE',
#  '2700 BLOCK TELEGRAPH AVE',
#  '2700 BLOCK WALKER ST',
#  '2700 BLOCK WEBSTER ST',
#  '2700 DWIGHT',
#  '2721 SHATTUCK AVE',
#  '2724 CHANNING WAY',
#  '2725 SOJOURNER TRUTH CT WAY',
#  '2747 2747 SAN PABLO AVE',
#  '2800 BLOCK 7TH ST',
#  '2800 BLOCK ACTON ST',
#  '2800 BLOCK ADELINE ST',
#  '2800 BLOCK ASHBY AVE',
#  '2800 BLOCK DERBY ST',
#  '2800 BLOCK ELLSWORTH ST',
#  '2800 BLOCK FULTON ST',
#  '2800 BLOCK HILGARD AVE',
#  '2800 BLOCK HILLEGASS AVE',
#  '2800 BLOCK MABEL ST',
#  '2800 BLOCK MARTIN LUTHER KING JR WAY',
#  '2800 BLOCK MILVIA ST',
#  '2800 BLOCK PARK ST',
#  '2800 BLOCK PIEDMONT AVE',
#  '2800 BLOCK PRINCE ST',
#  '2800 BLOCK REGENT ST',
#  '2800 BLOCK SACRAMENTO ST',
#  '2800 BLOCK SAN PABLO AVE',
#  '2800 BLOCK SHASTA RD',
#  '2800 BLOCK SHATTUCK AVE',
#  '2800 BLOCK STANTON ST',
#  '2800 BLOCK TELEGRAPH AVE',
#  '2800 BLOCK WEBSTER ST',
#  '2800 BLOCK WOOLSEY ST',
#  '2807 TELEGRAPH AVE',
#  '2828 PALM CT',
#  '2834 SACRAMENTO ST',
#  '2887 COLLEGE AVE',
#  '2900 BLOCK ACTON ST',
#  '2900 BLOCK ADELINE ST',
#  '2900 BLOCK ASHBY AVE',
#  '2900 BLOCK DEAKIN ST',
#  '2900 BLOCK DERBY ST',
#  '2900 BLOCK DOHR ST',
#  '2900 BLOCK DOMINGO AVE',
#  '2900 BLOCK ELLIS ST',
#  '2900 BLOCK ELLSWORTH ST',
#  '2900 BLOCK FLORENCE ST',
#  '2900 BLOCK FULTON ST',
#  '2900 BLOCK HARPER ST',
#  '2900 BLOCK MABEL ST',
#  '2900 BLOCK MARTIN LUTHER KING JR WAY',
#  '2900 BLOCK NEWBURY ST',
#  '2900 BLOCK PIEDMONT AVE',
#  '2900 BLOCK REGENT ST',
#  '2900 BLOCK SACRAMENTO ST',
#  '2900 BLOCK SAN PABLO AVE',
#  '2900 BLOCK SHASTA RD',
#  '2900 BLOCK SHATTUCK AVE',
#  '2900 BLOCK STANTON ST',
#  '2900 BLOCK TELEGRAPH AVE',
#  '2900 BLOCK WHEELER ST',
#  '2904 OTIS ST',
#  '2910 BENVENUE AVE',
#  '2931 STANTON ST',
#  '2951 DERBY ST',
#  '2996 TELEGRAPH AVE',
#  '300 BLOCK VERMONT AVE',
#  '3000 BLOCK ACTON ST',
#  '3000 BLOCK ADELINE ST',
#  '3000 BLOCK ASHBY AVE',
#  '3000 BLOCK DANA ST',
#  '3000 BLOCK DEAKIN ST',
#  '3000 BLOCK DOHR ST',
#  '3000 BLOCK ELLIS ST',
#  '3000 BLOCK FULTON ST',
#  '3000 BLOCK HARPER ST',
#  '3000 BLOCK MABEL ST',
#  '3000 BLOCK MARTIN LUTHER KING JR WAY',
#  '3000 BLOCK REGENT ST',
#  '3000 BLOCK SACRAMENTO ST',
#  '3000 BLOCK SAN PABLO AVE',
#  '3000 BLOCK SHATTUCK AVE',
#  '3000 BLOCK STANTON ST',
#  '3000 BLOCK TELEGRAPH AVE',
#  '3000 BLOCK TREMONT ST',
#  '3000 BLOCK WHEELER ST',
#  '3000 COLBY ST',
#  '3000 TELEGRAPH AVE',
#  '3015 SAN PABLO AVE',
#  '3047 DOHR ST',
#  '3049 SACRAMENTO ST',
#  '3100 BLOCK ADELINE ST',
#  '3100 BLOCK ELLIS ST',
#  '3100 BLOCK ETON AVE',
#  '3100 BLOCK HARPER ST',
#  '3100 BLOCK MABEL ST',
#  '3100 BLOCK MARTIN LUTHER KING JR WAY',
#  '3100 BLOCK SACRAMENTO ST',
#  '3100 BLOCK SAN PABLO AVE',
#  '3100 BLOCK SHATTUCK AVE',
#  '3100 BLOCK WHEELER ST',
#  '3140 CALIFORNIA ST',
#  '3200 BLOCK ADELINE ST',
#  '3200 BLOCK IDAHO ST',
#  '3200 BLOCK SACRAMENTO ST',
#  '3240 SACRAMENTO ST',
#  '3300 BLOCK ADELINE ST',
#  '3302 CALIFORNIA ST',
#  '3404 KING ST',
#  '400 BLOCK ARLINGTON AVE',
#  '400 BLOCK GRIZZLY PEAK BLVD',
#  '400 BLOCK VASSAR AVE',
#  '400 BLOCK VINCENTE AVE',
#  '400 GILMAN ST',
#  '401 GRIZZLY PEAK',
#  '500 BLOCK NEILSON ST',
#  '500 BLOCK PANORAMIC WAY',
#  '500 BLOCK SANTA CLARA AVE',
#  '500 BLOCK SPRUCE ST',
#  '500 BLOCK TUNNEL RD',
#  '500 BLOCK UNIVERSITY AVE',
#  '500 BLOCK WOODMONT AVE',
#  '500 VINCENTE AVE',
#  '58 PANORAMIC WAY',
#  '600 BLOCK ADDISON ST',
#  '600 BLOCK ASHBY AVE',
#  '600 BLOCK GILMAN ST',
#  '600 BLOCK HARRISON ST',
#  '600 BLOCK HEARST AVE',
#  '600 BLOCK HILLDALE AVE',
#  '600 BLOCK PAGE ST',
#  '600 BLOCK PERALTA AVE',
#  '600 BLOCK SAN LUIS RD',
#  '600 BLOCK SANTA BARBARA RD',
#  '600 BLOCK SPRUCE ST',
#  '600 BLOCK VINCENTE AVE',
#  '600 BLOCK VISTAMONT AVE',
#  '600 BLOCK WOODMONT AVE',
#  '6200 BLOCK SAN PABLO AVE',
#  '625 SAN LUIS RD',
#  '64 PANORAMIC WAY',
#  '700 BLOCK ADDISON ST',
#  '700 BLOCK ARLINGTON AVE',
#  '700 BLOCK ASHBY AVE',
#  '700 BLOCK ENSENADA AVE',
#  '700 BLOCK ESSEX WAY',
#  '700 BLOCK FOLGER AVE',
#  '700 BLOCK GRAYSON ST',
#  '700 BLOCK HARRISON ST',
#  '700 BLOCK HEARST AVE',
#  '700 BLOCK HEINZ AVE',
#  '700 BLOCK HILLDALE AVE',
#  '700 BLOCK PERALTA AVE',
#  '700 BLOCK POTTER ST',
#  '700 BLOCK SANTA BARBARA RD',
#  '700 BLOCK UNIVERSITY AVE',
#  '700 BLOCK WOODHAVEN RD',
#  '800 BLOCK ALLSTON WAY',
#  '800 BLOCK ANTHONY ST',
#  '800 BLOCK ARLINGTON AVE',
#  '800 BLOCK ASHBY AVE',
#  '800 BLOCK ENSENADA AVE',
#  '800 BLOCK GRAYSON ST',
#  '800 BLOCK GRIZZLY PEAK BLVD',
#  '800 BLOCK HEARST AVE',
#  '800 BLOCK INDIAN ROCK AVE',
#  '800 BLOCK JONES ST',
#  '800 BLOCK MENDOCINO AVE',
#  '800 BLOCK MIRAMAR AVE',
#  '800 BLOCK PERALTA AVE',
#  '800 BLOCK POTTER ST',
#  '800 BLOCK SHATTUCK AVE',
#  '800 BLOCK UNIVERSITY AVE',
#  '843 GILMAN ST',
#  '850 HEARST AVE',
#  '900 BLOCK ADDISON ST',
#  '900 BLOCK ALLSTON WAY',
#  '900 BLOCK ASHBY AVE',
#  '900 BLOCK DWIGHT WAY',
#  '900 BLOCK EUCLID AVE',
#  '900 BLOCK FRESNO AVE',
#  '900 BLOCK GILMAN ST',
#  '900 BLOCK GRIZZLY PEAK BLVD',
#  '900 BLOCK HEINZ AVE',
#  '900 BLOCK HILLDALE AVE',
#  '900 BLOCK INDIAN ROCK AVE',
#  '900 BLOCK JONES ST',
#  '900 BLOCK MENDOCINO AVE',
#  '900 BLOCK MODOC ST',
#  '900 BLOCK MURRAY ST',
#  '900 BLOCK PAGE ST',
#  '900 BLOCK PARKER ST',
#  '900 BLOCK REGAL RD',
#  '900 BLOCK SAN BENITO RD',
#  '900 BLOCK SPRUCE ST',
#  '900 BLOCK UNIVERSITY AVE',
#  '918 PARKER ST',
#  '950 HEARST AVE',
#  nan}

# %% [markdown]
# ## Question 4a: Similarity-based deduplication
#
# Assume we would like to write a function that takes a dataframe `df` and a threshold `t` as inputs, and returns the de-duplicated dataframe. Two rows are duplicates if the edit distance of `BLKADDR` column values are higher than the threshold.
#
# **Question** Calculate the number of comparisons needed for dataframe `calls_without_duplicate`.

# %%
number_of_comparisons = len(calls_without_duplicate)*(len(calls_without_duplicate)-1)/2
number_of_comparisons
# Out:
# 3454506.0

# %%
# Run the following function without any change!

def edit_distance(s1, s2):
    s1 = str(s1)
    s2 = str(s2)
    if s1 == 'nan' or s2 == 'nan':
        return 9999999
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

# %%
list_of_address = np.array(calls_without_duplicate['BLKADDR'])[:300]
counter = 0
for i in np.arange(len(list_of_address)):
    for j in np.arange(i+1, len(list_of_address)):
        if i>= j:
            continue
        edit_distance(list_of_address[i], list_of_address[j])
        counter += 1
print(counter)
# Out:
# 44850

# %% [markdown]
# Now, consider that we already know that the duplicate rows **MUST** have the same `CVLEGEND` value.
#
# **Question 4b** Knowing the aforementioned fact, calculate the number of comparisons.

# %%
count_series = calls_without_duplicate.groupby(['CVLEGEND'])['CVLEGEND'].count()
number_of_comparisons_groupped = 0
for count in count_series:
    number_of_comparisons_groupped += count*(count-1)/2
number_of_comparisons_groupped
# Out:
# 456673.0

# %% [markdown]
# ## Congratulations!
#
# Congrats! You are finished with this lab.
